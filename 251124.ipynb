# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv('Downloads/imdb_data.csv')
data1
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
#Q.01 WAP aa python Pandas program to get the columns of the imdb DataFrame

df=pd.read_csv('Downloads/imdb_data.csv')
#df
print(df.columns)
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
print(df.head())
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
#Q.02 WAP to get the info of the imdb_data set
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
#Q.03 WA pandas program to get the details of 4th movie of the DataFrame
print(df.iloc[3])
# Out:
# id                                                                       5
# belongs_to_collection                                                  NaN
# budget                                                                   0
# genres                   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# homepage                                                               NaN
# imdb_id                                                          tt1380152
# original_language                                                       ko
# original_title                                                        마린보이
# overview                 Marine Boy is the story of a former national s...
# popularity                                                         1.14807
# poster_path                               /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg
# production_companies                                                   NaN
# ...

# %%
#Q.04 WA p program to count no. of rows and columns of the DataFrame
print(df.shape)
# Out:
# (3000, 23)

# %%
#Q.5 WA Pandas program to get datails of the columns Bazat and title
print(df[['budget','title']])
# Out:
#         budget                                     title
# 0     14000000                    Hot Tub Time Machine 2
# 1     40000000  The Princess Diaries 2: Royal Engagement
# 2      3300000                                  Whiplash
# 3      1200000                                   Kahaani
# 4            0                                Marine Boy
# ...        ...                                       ...
# 2995         0                                   Chasers
# 2996         0                          We Are the Best!
# 2997  65000000                   The Long Kiss Goodnight
# 2998  42000000                          Along Came Polly
# 2999  35000000                                 Abduction
#
# [3000 rows x 2 columns]

# %%
#Q.06 Write a  pandas to get the detail of the movie with the name kahaani
print(df[df['title'] == 'Kahaani'])
print(df['title']=='Kahaani')
# Out:
#    id belongs_to_collection   budget  \
# 3   4                   NaN  1200000
#
#                                               genres  \
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
#
#                      homepage    imdb_id original_language original_title  \
# 3  http://kahaanithefilm.com/  tt1821480                hi        Kahaani
#
#                                             overview  popularity  ...  \
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
#
#   release_date runtime                                   spoken_languages  \
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status  tagline    title  \
# 3  Released      NaN  Kahaani
#
#                                             Keywords  \
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
#
#                                                 cast  \
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
#
# ...

# %%
#Q.07 Write a pandas pro to short imdb data based on budget

#print(df.sort_values(by='budget' ,ascending=False))
print(df.sort_values(by='budget'))
# Out:
#         id                              belongs_to_collection     budget  \
# 895    896                                                NaN          0
# 594    595                                                NaN          0
# 595    596                                                NaN          0
# 1252  1253                                                NaN          0
# 2144  2145                                                NaN          0
# ...    ...                                                ...        ...
# 1630  1631  [{'id': 8650, 'name': 'Transformers Collection...  260000000
# 1425  1426  [{'id': 8537, 'name': 'Superman Collection', '...  270000000
# 2770  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 2209  2210  [{'id': 295, 'name': 'Pirates of the Caribbean...  300000000
# 2135  2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
#
#                                                  genres  \
# ...
