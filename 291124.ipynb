# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.8.4'

# %%
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3],[4,5,1])
plt.show()

# %%
x=[5,2,7]
y=[1,10,4]
plt.plot(x,y)
plt.title('Line graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
plt.plot([1,2,3,4,5])
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25])
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],'ro')
#itemsolve movie
#chifminister
#shabd movie

#plt.plot([1,2,3,4,5],[1,4,9,16,25],'b') #blue
#plt.plot([1,2,3,4,5],[1,4,9,16,25],'g') # green circle
#plt.plot([1,2,3,4,5],[1,4,9,16,25],'--') # a dashed line with the defult color
#plt.plot([1,2,3,4,5],[1,4,9,16,25],'^k:') # Black tringle
plt.axis([0,6,0,20]) #axis kaha tak kya dena hai
plt.show()

# %%
import numpy as np
data=np.random.normal(size=100)
print(data)
plt.hist(data,bins=10)
plt.show()
# Out:
# [-0.77161314 -1.63067623  0.58717095  0.2778321   1.90865947  0.8753054
#  -0.83727047  0.20182687 -0.49306388 -0.89494553 -0.17051325  0.55083468
#  -0.62133145 -0.60241367 -1.1547908  -1.694328    0.02246556  1.66844239
#   0.04128074 -0.97535518  0.79887346  1.284935   -0.41253644  1.69613726
#   0.12913727 -0.59224576 -0.48654436 -1.2237766   0.15649664 -0.39754157
#   0.51962371 -0.24612138  0.92952106  0.36400012  2.19486397  0.62032613
#  -0.23477748  0.62596128  2.00686321 -0.63337654 -0.09727418 -2.61176556
#  -0.21958863  0.07095573 -0.39616326  0.26216451  0.02247357 -0.10931706
#  -0.26162898 -0.05489971  0.22030942 -0.50095349  0.0995721   1.42559914
#  -1.07246537  0.96990176 -0.22434446 -1.3548229  -1.05922929  0.12468138
#  -0.69697047 -0.87087421 -0.0407091  -0.17332724 -1.42984975  0.96105432
#   0.07773714 -1.34281946  0.91646379  1.24037808 -0.50622129 -1.19379737
#   2.76233062  0.74896805  0.19432819 -0.10375336 -0.9346539  -0.17316634
# ...
